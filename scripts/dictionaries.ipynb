# %%
from collections import defaultdict
import csv

# declare the dictionaries
parties = defaultdict(str) # key = president names, value = political party
# parties = {} # this is a normal dictionary, not a defaultdict
party_count = defaultdict(int) # key = political party, value = number of presidents in that party
presidents = defaultdict(str) # key = president number, value = president name

# Open the presidents.csv
input_file = "../../files/data/presidents.csv"
with open(input_file, "r") as data:
    librarian = csv.reader(data, delimiter=",")
    # we want to skip the header line
    header = next(librarian)
    for line in librarian:
        # print(line,end='')
        # line = line.strip() <- depreciated
            # split each line into a list <- depreciated
            # generally, we don't want to split the line ourselves
            # columns = line.split(",") # there's a module that does this for us

        # load the president dictionary
        # we can also assign names to the different columns
        # presidents[columns[0]] = columns[1] <- depreciated
        # each line is a list now

        # load the parties dictionary
        # parties[columns[1]] = columns[5] <- depreciated
        num = line[0].strip()
        name = line[1].strip()
        presidents[num] = name
        parties[name] = line[5].strip()


        party_count[parties[name]] += 1
# Out:
# <_csv.reader object at 0x7b2c35cea570>

# %%
# let's get stuff from our dictionaries
print(presidents.get('16')) # get the name of the 16th president
print(parties.get(presidents.get('16'))) # get the political party of the 16th president
# Out:
# Abraham Lincoln
# Republican/National Union

# %%
# loop over the dictionaries
for num in presidents.keys():
    print(f"President {num} was {presidents[num]} and was a member of the {parties[presidents[num]]} party.")
# Out:
# President 1 was George Washington and was a member of the Independent party.
# President 2 was John Adams and was a member of the Federalist party.
# President 3 was Thomas Jefferson and was a member of the Democratic-Republican party.
# President 4 was James Madison and was a member of the Democratic-Republican party.
# President 5 was James Monroe and was a member of the Democratic-Republican party.
# President 6 was John Quincy Adams and was a member of the Democratic-Republican/National Republican party.
# President 7 was Andrew Jackson and was a member of the Democratic party.
# President 8 was Martin Van Buren and was a member of the Democratic party.
# President 9 was William Henry Harrison and was a member of the Whig party.
# President 10 was John Tyler and was a member of the Whig party.
# President 11 was James K. Polk and was a member of the Democratic party.
# President 12 was Zachary Taylor and was a member of the Whig party.
# President 13 was Millard Fillmore and was a member of the Whig party.
# President 14 was Franklin Pierce and was a member of the Democratic party.
# President 15 was James Buchanan and was a member of the Democratic party.
# President 16 was Abraham Lincoln and was a member of the Republican/National Union party.
# President 17 was Andrew Johnson and was a member of the Democratic/National Union party.
# President 18 was Ulysses S. Grant and was a member of the Republican party.
# President 19 was Rutherford B. Hayes and was a member of the Republican party.
# President 20 was James A. Garfield and was a member of the Republican party.
# President 21 was Chester A. Arthur and was a member of the Republican party.
# President 22 was Grover Cleveland and was a member of the Democratic party.
# President 23 was Benjamin Harrison and was a member of the Republican party.
# President 24 was Grover Cleveland (2nd term) and was a member of the Democratic party.
# President 25 was William McKinley and was a member of the Republican party.
# President 26 was Theodore Roosevelt and was a member of the Republican party.
# President 27 was William Howard Taft and was a member of the Republican party.
# President 28 was Woodrow Wilson and was a member of the Democratic party.
# President 29 was Warren G. Harding and was a member of the Republican party.
# President 30 was Calvin Coolidge and was a member of the Republican party.
# President 31 was Herbert Hoover and was a member of the Republican party.
# President 32 was Franklin D. Roosevelt and was a member of the Democratic party.
# President 33 was Harry S. Truman and was a member of the Democratic party.
# President 34 was Dwight D. Eisenhower and was a member of the Republican party.
# President 35 was John F. Kennedy and was a member of the Democratic party.
# President 36 was Lyndon B. Johnson and was a member of the Democratic party.
# President 37 was Richard Nixon and was a member of the Republican party.
# President 38 was Gerald Ford and was a member of the Republican party.
# President 39 was Jimmy Carter and was a member of the Democratic party.
# President 40 was Ronald Reagan and was a member of the Republican party.
# President 41 was George H. W. Bush and was a member of the Republican party.
# President 42 was Bill Clinton and was a member of the Democratic party.
# President 43 was George W. Bush and was a member of the Republican party.
# President 44 was Barack Obama and was a member of the Democratic party.

# %%
# instead of printing, let's write out the output
outfile = open("../../files/data/pres.out", "w")

# Another way to loop over a dictionary
for num, name in presidents.items():
    outfile.write(f"President {num} was {name} and was a member of the {parties[name]} party.\n")
# the data doesn't get written out until we close the file
outfile.close()
# This doesn't handle the first line

# %%
for parties, count in party_count.items():
    print(f"There were {count} presidents in the {parties} party.")
# Out:
# There were 1 presidents in the Independent party.
# There were 1 presidents in the Federalist party.
# There were 3 presidents in the Democratic-Republican party.
# There were 1 presidents in the Democratic-Republican/National Republican party.
# There were 15 presidents in the Democratic party.
# There were 4 presidents in the Whig party.
# There were 1 presidents in the Republican/National Union party.
# There were 1 presidents in the Democratic/National Union party.
# There were 17 presidents in the Republican party.

# %%
# we are going to test this function here
from collections import defaultdict
import csv

start_position=defaultdict(int)
end_position=defaultdict(int)
sequence_id=defaultdict(str)
gff_input = "../../files/data/covid_genome/covid_genes.gff3"
with open(gff_input) as gff_file:
    gff_library=csv.reader(gff_file, delimiter="\t")
    for line in gff_library:
        start_position = line[3].strip()
        end_position = line[4].strip()
        sequence_id = line[8].strip()
        print(f"{sequence_id} starts at {start_position} and ends at {end_position}")
# Out:
# ID=cds-YP_009724389.1;Parent=gene-GU280_gp01;Dbxref=Genbank:YP_009724389.1,GeneID:43740578;Name=YP_009724389.1;Note=pp1ab%3B translated by -1 ribosomal frameshift;exception=ribosomal slippage;gbkey=CDS;gene=ORF1ab;locus_tag=GU280_gp01;product=ORF1ab polyprotein;protein_id=YP_009724389.1 starts at 266 and ends at 13468
# ID=cds-YP_009725295.1;Parent=gene-GU280_gp01;Dbxref=Genbank:YP_009725295.1,GeneID:43740578;Name=YP_009725295.1;Note=pp1a;gbkey=CDS;gene=ORF1ab;locus_tag=GU280_gp01;product=ORF1a polyprotein;protein_id=YP_009725295.1 starts at 266 and ends at 13483
# ID=ORF1ab starts at 266 and ends at 21555
# ID=cds-YP_009724389.1;Parent=gene-GU280_gp01;Dbxref=Genbank:YP_009724389.1,GeneID:43740578;Name=YP_009724389.1;Note=pp1ab%3B translated by -1 ribosomal frameshift;exception=ribosomal slippage;gbkey=CDS;gene=ORF1ab;locus_tag=GU280_gp01;product=ORF1ab polyprotein;protein_id=YP_009724389.1 starts at 13468 and ends at 21555
# ID=id-GU280_gp01;Dbxref=GeneID:43740578;function=Coronavirus frameshifting stimulation element stem-loop 1;gbkey=stem_loop;gene=ORF1ab;inference=COORDINATES: profile:Rfam-release-14.1:RF00507%2CInfernal:1.1.2;locus_tag=GU280_gp01 starts at 13476 and ends at 13503
# ID=id-GU280_gp01-2;Dbxref=GeneID:43740578;function=Coronavirus frameshifting stimulation element stem-loop 2;gbkey=stem_loop;gene=ORF1ab;inference=COORDINATES: profile:Rfam-release-14.1:RF00507%2CInfernal:1.1.2;locus_tag=GU280_gp01 starts at 13488 and ends at 13542
# ID=cds-YP_009724390.1;Parent=gene-GU280_gp02;Dbxref=Genbank:YP_009724390.1,GeneID:43740568;Name=YP_009724390.1;Note=structural protein%3B spike protein;gbkey=CDS;gene=S;locus_tag=GU280_gp02;product=surface glycoprotein;protein_id=YP_009724390.1 starts at 21563 and ends at 25384
# ID=spike glycoprotein starts at 21563 and ends at 25384
# ID=cds-YP_009724391.1;Parent=gene-GU280_gp03;Dbxref=Genbank:YP_009724391.1,GeneID:43740569;Name=YP_009724391.1;gbkey=CDS;gene=ORF3a;locus_tag=GU280_gp03;product=ORF3a protein;protein_id=YP_009724391.1 starts at 25393 and ends at 26220
# ID=ORF3a starts at 25393 and ends at 26220
# ID=cds-YP_009724392.1;Parent=gene-GU280_gp04;Dbxref=Genbank:YP_009724392.1,GeneID:43740570;Name=YP_009724392.1;Note=ORF4%3B structural protein%3B E protein;gbkey=CDS;gene=E;locus_tag=GU280_gp04;product=envelope protein;protein_id=YP_009724392.1 starts at 26245 and ends at 26472
# ID=geneE starts at 26245 and ends at 26472
# ID=cds-YP_009724393.1;Parent=gene-GU280_gp05;Dbxref=Genbank:YP_009724393.1,GeneID:43740571;Name=YP_009724393.1;Note=ORF5%3B structural protein;gbkey=CDS;gene=M;locus_tag=GU280_gp05;product=membrane glycoprotein;protein_id=YP_009724393.1 starts at 26523 and ends at 27191
# ID=geneM starts at 26523 and ends at 27191
# ID=cds-YP_009724394.1;Parent=gene-GU280_gp06;Dbxref=Genbank:YP_009724394.1,GeneID:43740572;Name=YP_009724394.1;gbkey=CDS;gene=ORF6;locus_tag=GU280_gp06;product=ORF6 protein;protein_id=YP_009724394.1 starts at 27202 and ends at 27387
# ID=ORF6 starts at 27202 and ends at 27387
# ID=cds-YP_009724395.1;Parent=gene-GU280_gp07;Dbxref=Genbank:YP_009724395.1,GeneID:43740573;Name=YP_009724395.1;gbkey=CDS;gene=ORF7a;locus_tag=GU280_gp07;product=ORF7a protein;protein_id=YP_009724395.1 starts at 27394 and ends at 27759
# ID=ORF7a starts at 27394 and ends at 27759
# ID=cds-YP_009725318.1;Parent=gene-GU280_gp08;Dbxref=Genbank:YP_009725318.1,GeneID:43740574;Name=YP_009725318.1;gbkey=CDS;gene=ORF7b;locus_tag=GU280_gp08;product=ORF7b;protein_id=YP_009725318.1 starts at 27756 and ends at 27887
# ID=ORF7b starts at 27756 and ends at 27887
# ID=cds-YP_009724396.1;Parent=gene-GU280_gp09;Dbxref=Genbank:YP_009724396.1,GeneID:43740577;Name=YP_009724396.1;gbkey=CDS;gene=ORF8;locus_tag=GU280_gp09;product=ORF8 protein;protein_id=YP_009724396.1 starts at 27894 and ends at 28259
# ID=ORF8NC_045512.2 starts at 27894 and ends at 28259
# ID=geneN starts at 28274 and ends at 29533
# ID=cds-YP_009725255.1;Parent=gene-GU280_gp11;Dbxref=Genbank:YP_009725255.1,GeneID:43740576;Name=YP_009725255.1;gbkey=CDS;gene=ORF10;locus_tag=GU280_gp11;product=ORF10 protein;protein_id=YP_009725255.1 starts at 29558 and ends at 29674
# ID=ORF10 starts at 29558 and ends at 29674
# ID=id-GU280_gp11;Dbxref=GeneID:43740576;function=Coronavirus 3' UTR pseudoknot stem-loop 1;gbkey=stem_loop;gene=ORF10;inference=COORDINATES: profile::Rfam-release-14.1:RF00165%2CInfernal:1.1.2;locus_tag=GU280_gp11 starts at 29609 and ends at 29644
# ID=id-GU280_gp11-2;Dbxref=GeneID:43740576;function=Coronavirus 3' UTR pseudoknot stem-loop 2;gbkey=stem_loop;gene=ORF10;inference=COORDINATES: profile::Rfam-release-14.1:RF00165%2CInfernal:1.1.2;locus_tag=GU280_gp11 starts at 29629 and ends at 29657

# %%
fasta_input = "../../files/data/covid_genome/covid.fasta"
with open(fasta_input, "r") as fasta_file:
    genome=csv.reader(fasta_file)
    header = next(genome)
    for line in genome:
        test=line.strip("\n")
        print(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 6
#       4 header = next(genome)
#       5 for line in genome:
# ----> 6     test=line.strip("\n")
#       7     print(test)
#
# AttributeError: 'list' object has no attribute 'strip'
