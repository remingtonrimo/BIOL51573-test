# %% [markdown]
# # heading
# ## sub-heading
# ### sub-sub-heading
# #### sub-sub-sub-heading
#
# bulleted list:
# - iqtree
# - raxml
# - beast
#
# number list:
# 1. first
# 2. second
# 3. third
# 4. fourth
#
# this is a code block: './hello_world.py'

# %%
print("hello world")
print(7+9)
# Out:
# hello world
# 16
